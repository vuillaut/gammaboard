# %%
# %matplotlib notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import gammaboard as gabo
gb = gabo.GammaBoard('/Users/thomas/Work/CTA/Data/experiments/', site='south', ref='performances') # ref can also be None or 'requirements'
# gb = gabo.GammaBoard('/home/mikael/lst_bootcamp_gl_data/')
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
gb.exp_box
# Out:
# HBox(children=(VBox(children=(Button(button_style='warning', description='R_RF_20190402_cuts', layout=Layout(m…

# %%
exp = gb.experiments_dict['R_RF_20190402']
exp.load_data()
fig = gabo.plot_migration_matrices(exp, figsize=(20,4))
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
import ctaplot

# %%
# %matplotlib inline
ctaplot.plot_effective_area_per_energy_power_law(1e-3, 1e3, 100000, -2, exp.data.reco_energy, 1e7)

# %%
import numpy as np

# %%
exp.mask = exp.data.disp_norm < 0.1

# %%
filter = np.ones(len(exp.data), dtype=bool)

# %%
filter = filter & (exp.data.disp_norm < 0.1)

# %%
exp.data[filter]
# Out:
#      disp_angle   disp_dx   disp_dy  disp_miss  disp_norm  disp_sign  \
# 2      0.011262  0.099954  0.001126   0.072924   0.099961        1.0
# 135   -0.286114  0.088194 -0.025945   0.056972   0.091931        1.0
# 15     1.498649 -0.003607 -0.049912   0.042958   0.050042       -1.0
# 14    -1.547204 -0.002190  0.092814   0.020580   0.092840       -1.0
# 120   -0.092126  0.031375 -0.002899   0.023380   0.031508        1.0
# 8     -1.180292 -0.024148  0.058661   0.017513   0.063437       -1.0
# 102   -1.453890  0.006016 -0.051226   0.050589   0.051578        1.0
# 84    -0.152923 -0.063968  0.009859   0.063374   0.064724       -1.0
# 18     1.522441 -0.000708 -0.014636   0.011546   0.014653       -1.0
# 104   -1.384350  0.009984 -0.052928   0.030688   0.053861        1.0
# 83     0.577068  0.063373  0.041255   0.035389   0.075618        1.0
# 150    0.766714  0.054374  0.052379   0.072841   0.075499        1.0
# 114   -0.745786  0.061722 -0.057016   0.038073   0.084026        1.0
# 31     1.521202 -0.004637 -0.093422   0.004341   0.093537       -1.0
# 85    -0.788356 -0.028378  0.028546   0.035563   0.040251       -1.0
# 108    1.211144 -0.009182 -0.024420   0.008880   0.026089       -1.0
# 1      0.580325  0.082559  0.054128   0.084558   0.098721        1.0
# 32     1.110849  0.037773  0.076250   0.072094   0.085093        1.0
# 128   -0.756386  0.070009 -0.066060   0.095816   0.096256        1.0
# 96    -0.843626 -0.062414  0.070142   0.038376   0.093890       -1.0
# 109    0.483784  0.054953  0.028874   0.046338   0.062076        1.0
# 124   -1.450155  0.004851 -0.040015   0.017439   0.040308        1.0
# 142    0.392493 -0.081640 -0.033797   0.079725   0.088359       -1.0
# 107   -1.227616 -0.003216  0.009002   0.001952   0.009559       -1.0
# 24     1.408231 -0.010683 -0.065138   0.033789   0.066008       -1.0
# 0     -1.263902  0.009404 -0.029674   0.027773   0.031129        1.0
# 60    -0.384494 -0.009961  0.004031   0.009555   0.010745       -1.0
# 125    0.239331  0.054146  0.013212   0.055626   0.055735        1.0
# 12     1.077740 -0.031431 -0.058497   0.041995   0.066406       -1.0
# 109   -0.353329  0.046770 -0.017249   0.040736   0.049849        1.0
# 16   0.975134  0.023035  0.240928     1.258374    3.153466       1.244393
# 76   0.671411  0.786063  0.440060     1.242965    3.228847       1.258976
# 125  0.317136 -0.731761  0.251199     1.233539    3.057575       1.229505
# 94  -0.607457  0.755856  0.547174     1.200230    3.219201       1.198225
# 21   0.835859 -0.189632  0.380294     1.251442    3.111958       1.251348
# 16   0.385204  0.815910  0.049325     1.233877    3.232306       1.234881
# 48  -0.772788 -0.440373  0.788107     1.195555    3.100839       1.193164
# 85   0.082256  0.847482  0.369257     1.222006    3.234677       1.222240
# 42  -0.985079 -0.071573  0.437062     1.189841    3.135788       1.176921
# 73   0.603651  0.692719  0.460505     1.243279    3.210107       1.241339
# 106  0.823804 -0.015061  0.847668     1.253069    3.136829       1.250280
# 4    0.821073  0.092255  0.686891     1.249443    3.149136       1.250977
# 63  -0.183219  0.380984  0.693124     1.212028    3.183859       1.214258
#
#      reco_azimuth  reco_energy
# 2        3.098617     0.052149
# 135      3.056610     0.038544
# 15       3.135058     0.027352
# 14       3.199710     0.019757
# 120      3.199594     0.022576
# 8        3.096112     0.029002
# 102      3.100492     0.050982
# 84       3.202524     0.024312
# 18       3.004894     0.049316
# 104      3.132632     0.186036
# 83       3.330118     0.116791
# 150      3.138193     0.022451
# 114      3.080068     0.031396
# 31       3.116696     0.024694
# 85       3.058849     0.122237
# 108      3.072357     0.047324
# 1        3.107256     0.175620
# 32       3.060474     0.020617
# 128      3.018923     0.148115
# 96       3.198983     0.030842
# 109      3.023380     0.069574
# 124      3.038176     0.064781
# 142      3.134254     0.173861
# 107      3.130143     0.039611
# 24       3.097572     0.031739
# 0        3.192459     0.204766
# 60       3.071059     0.034451
# 125      3.082089     0.040709
# 12       3.134843     0.024162
# 109      3.064876     0.161599
# ..            ...          ...
# 100      3.144417     0.041673
# 56       3.240214     0.101764
# 155      3.116186     0.047874
# 47       3.173246     0.040754
# 9        3.156659     0.049322
# 6        3.066175     0.082448
# 129      3.070051     0.027332
# 124      3.239956     0.096208
# 92       3.232225     0.040044
# 12       3.129126     0.052904
# 60       3.158249     0.027480
# 116      3.173537     0.083278
# 63       3.174761     0.047644
# 151      3.101286     0.070054
# 50       3.160311     0.025917
# 43       3.108170     0.209632
# 47       3.207286     0.032256
# 16       3.092574     0.087707
# 76       3.250146     0.416214
# 125      3.117065     0.052436
# 94       3.227366     0.041689
# 21       3.124307     0.038767
# 16       3.271354     0.128556
# 48       3.099894     0.037635
# 85       3.191362     0.068736
# 42       3.118209     1.050225
# 73       3.214861     0.039075
# 106      3.149554     0.042853
# 4        3.150557     0.029358
# 63       3.155681     0.378716
#
# [1812 rows x 41 columns]

# %%
exp.mask = np.ones(len(exp.data), dtype=bool)

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
import ctaplot

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# line, = ax.plot(x, np.sin(x))
ax = ctaplot.plot_angular_res_per_energy(exp.data[exp.mask].reco_altitude,
                                         exp.data[exp.mask].reco_azimuth,
                                         exp.data[exp.mask].mc_altitude,
                                         exp.data[exp.mask].mc_azimuth,
                                         exp.data[exp.mask].mc_energy,
                                         ax=ax,
                                        )

plt.tight_layout()

def update(disp_norm_max=0.6):
    exp.mask = exp.data.disp_norm < disp_norm_max
    new_ax = ctaplot.plot_angular_res_per_energy(exp.data[exp.mask].reco_altitude,
                                         exp.data[exp.mask].reco_azimuth,
                                         exp.data[exp.mask].mc_altitude,
                                         exp.data[exp.mask].mc_azimuth,
                                         exp.data[exp.mask].mc_energy,
                                        )
    fig.canvas.draw()

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.6, description='disp_norm_max', max=1.7999999999999998, min=-0.6), O…

# %%
ctaplot.ana.angular_resolution_per_energy

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw()

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…

# %%
ax.plot(x, np.sin(x))

# %%
ax = ctaplot.plot_angular_res_per_energy(exp.data[exp.mask].reco_altitude,
                                         exp.data[exp.mask].reco_azimuth,
                                         exp.data[exp.mask].mc_altitude,
                                         exp.data[exp.mask].mc_azimuth,
                                         exp.data[exp.mask].mc_energy,
                                        )

# %%
ax.lines
# Out:
# [<matplotlib.lines.Line2D at 0x1a1e8c0278>,
#  <matplotlib.lines.Line2D at 0x1a1f7e8eb8>,
#  <matplotlib.lines.Line2D at 0x1a238314a8>,
#  <matplotlib.lines.Line2D at 0x1a1c226128>]

# %%
col = exp.data['disp_norm']

widg = widgets.FloatRangeSlider(
    min=col.min(),
    max=col.max(),
    step=0.1,
    readout=True,
    readout_format='.1f',
)

# %%
mask = (col > widg.get_state()['value'][0]) & (col < widg.get_state()['value'][1])

# %%
import numpy as np

# %%
mask = np.ma.nomask

# %%
np.ma.array(col, mask=mask)
# Out:
# masked_array(data=[0.51321265, 0.40282881, 0.17518554, ..., 0.88580552,
#                    0.53555453, 0.46166264],
#              mask=False,
#        fill_value=1e+20)

# %%
ctaplot.plot_

# %%
10**(6 * np.random.rand(10) - 3)
# Out:
# array([1.04781399e+00, 5.41497465e+00, 6.09239023e+01, 6.94582238e-02,
#        4.20595339e-01, 2.09930133e+02, 4.40890750e-03, 1.70606138e-03,
#        6.62022829e-01, 2.65503469e+00])

# %%
import numpy as np
import matplotlib.pyplot as plt
import ctaplot

# %%
f = plt.figure()
plt.hist(np.log10(exp.data.reco_energy), bins=50);

# %%
f =plt.figure()
ctaplot.plot_energy_bias(exp.data.mc_energy, exp.data.reco_energy)
plt.show()

# %%
f =plt.figure()
ctaplot.plot_energy_resolution(exp.data.mc_energy, exp.data.reco_energy, bias_correction=False)
ctaplot.plot_energy_resolution(exp.data.mc_energy, exp.data.reco_energy, bias_correction=True)
ctaplot.plot_energy_resolution_requirements('south')
ctaplot.plot_energy_resolution_cta_performances('south')
plt.show()

# %%
energy_error = exp.data.mc_energy - exp.data.reco_energy
fig = plt.figure()
n, bins, patches = plt.hist(energy_error, bins=1000)
plt.show()

# %%
energy_error.max()

# %%
energy_error.min()

# %%
exp.data
